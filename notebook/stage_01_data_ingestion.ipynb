# %%
import os

# %%
from kalimati_tarkari.config import mongo_db_connection

# %%
from kalimati_tarkari.data_acess.kalimati_data import KalimatiData

# %%
from kalimati_tarkari.constants import *

# %%
password
# Out:
# 'Bismuth@123'

# %%
MONGODB_URL_KEY
# Out:
# 'mongodb+srv://bishwajyotichaudhary46:Bismuth%40123@cluster0.tofa7.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
from kalimati_tarkari.config.mongo_db_connection import MongoDBClient

# %%
obj = MongoDBClient()

# %%
collection = obj.database[COLLECTION_NAME]

# %%
list(collection.find())
# Out:
# [{'_id': ObjectId('66f50f456932b4064f1ab7d0'), 'Average': 19.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7dc'), 'Average': 19.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7d2'), 'Average': 19.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7d7'), 'Average': 18.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7e5'), 'Average': 19.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7f9'), 'Average': 20.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7fc'), 'Average': 20.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7cd'), 'Average': 15.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7cf'), 'Average': 18.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7e8'), 'Average': 19.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7d1'), 'Average': 19.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab800'), 'Average': 21.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7e1'), 'Average': 18.0},
#  {'_id': ObjectId('66f50f456932b4064f1ab7e3'), 'Average': 19.0},
# ...

# %%
data = KalimatiData()

# %%
df = data.export_collection_as_dataframe(COLLECTION_NAME)
# Out:
#       Average
# 0       19.00
# 1       19.00
# 2       19.00
# 3       18.00
# 4       19.00
# ...       ...
# 4001    70.00
# 4002    68.00
# 4003    67.33
# 4004    67.33
# 4005    70.00
#
# [4006 rows x 1 columns]

# %%
from kalimati_tarkari.utils.main_utils import read_yaml

# %%
from kalimati_tarkari.config.configuration import ConfigurationManager
from kalimati_tarkari.components.data_ingestion import DataIngestion
from kalimati_tarkari.logger import logging

# %% [markdown]
# %pwd

# %%
import os

# %%
# %pwd
# Out:
# 'f:\\Unversity\\Project\\TimeSeries\\Kalimati-tarkari\\notebook'

# %%
os.chdir("../")

# %%
# Out:
# mongodb+srv://bishwajyotichaudhary46:Bismuth%40123@cluster0.tofa7.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
#       Average
# 0       15.00
# 1       17.00
# 2       18.00
# 3       19.00
# 4       19.00
# ...       ...
# 4001    76.67
# 4002    62.67
# 4003    77.67
# 4004    79.00
# 4005    80.00
#
# [4006 rows x 1 columns]

# %%
class DataIngestionTrainingPipeline:
    def __init__(self):
        pass

    def main(self):
        try:
            config = ConfigurationManager()
            data_ingestion_config = config.get_data_ingestion_config()
            data_ingestion = DataIngestion(data_ingestion_config=data_ingestion_config)
            data_ingestion.export_data_into_feature_store()
        except Exception as e:
            raise e
