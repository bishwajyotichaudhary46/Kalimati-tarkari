# %%
print("ok")
# Out:
# ok

# %%
'''
mongodb+srv://bishwajyotichaudhary46:Bismuth@123@cluster0.tofa7.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
'''
# Out:
# '\nmongodb+srv://bishwajyotichaudhary46:Bismuth@123@cluster0.tofa7.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0\n'

# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
df = pd.read_csv("final_data.csv")

# %%
devanagari_to_english = {
    '०': '0', '१': '1', '२': '2', '३': '3', '४': '4',
    '५': '5', '६': '6', '७': '7', '८': '8', '९': '9'
}

def replace_devanagari_with_eng(text):
    for dev, eng in devanagari_to_english.items():
        text = text.replace(dev, eng)
    return text

# %%
df_potato= df[df['Commodity'] == 'आलु रातो']
df_potato = df_potato[['Date', 'Average']]
start_date = datetime(2013, 4, 15)
end_date = datetime.now()
df_potato
# Out:
#               Date   Average
# 2       04/15/2013  रू १५.००
# 74      04/16/2013  रू १७.००
# 144     04/17/2013  रू १८.००
# 214     04/18/2013  रू १९.००
# 294     04/21/2013  रू १९.००
# ...            ...       ...
# 320341  09/25/2024  रू ७९.००
# 320435  09/26/2024  रू ८०.००
# 320531  09/27/2024  रू ७७.६७
# 320627  09/28/2024  रू ७७.६७
# 320718  09/29/2024  रू ७८.३३
#
# [4009 rows x 2 columns]

# %%
 # Generate the range of dates for the year 2024
date_range = []
current = start_date
end_date = datetime.now()
while current <= end_date:
    date_range.append(current.strftime('%m/%d/%Y'))
    current += timedelta(days=1)

date_range = pd.Index(date_range)
complete_df = pd.DataFrame(date_range, columns=['Date'])
complete_df
# Out:
#             Date
# 0     04/15/2013
# 1     04/16/2013
# 2     04/17/2013
# 3     04/18/2013
# 4     04/19/2013
# ...          ...
# 4182  09/26/2024
# 4183  09/27/2024
# 4184  09/28/2024
# 4185  09/29/2024
# 4186  09/30/2024
#
# [4187 rows x 1 columns]

# %%
df_potato

# %%
final_df = pd.merge(complete_df,df_potato, on=['Date'], how='left')

# %%
final_df
# Out:
#             Date   Average
# 0     04/15/2013  रू १५.००
# 1     04/16/2013  रू १७.००
# 2     04/17/2013  रू १८.००
# 3     04/18/2013  रू १९.००
# 4     04/19/2013       NaN
# ...          ...       ...
# 4182  09/26/2024  रू ८०.००
# 4183  09/27/2024  रू ७७.६७
# 4184  09/28/2024  रू ७७.६७
# 4185  09/29/2024  रू ७८.३३
# 4186  09/30/2024       NaN
#
# [4187 rows x 2 columns]

# %%
df_potato['Average'] = df_potato['Average'].str.replace("रू","")

# %%
df_potato['Average'] = df_potato['Average'].astype('str').apply(replace_devanagari_with_eng).astype('float')

# %%
df_potato
# Out:
#               Date  Average
# 2       2013-04-15    15.00
# 74      2013-04-16    17.00
# 144     2013-04-17    18.00
# 214     2013-04-18    19.00
# 294     2013-04-21    19.00
# ...            ...      ...
# 319871  2024-09-20    76.67
# 320154  2024-09-23    62.67
# 320248  2024-09-24    77.67
# 320341  2024-09-25    79.00
# 320435  2024-09-26    80.00
#
# [4006 rows x 2 columns]

# %%
df_potato.set_index('Date', inplace=True)

# %%
df_potato
# Out:
#             Average
# Date
# 2013-04-15    15.00
# 2013-04-16    17.00
# 2013-04-17    18.00
# 2013-04-18    19.00
# 2013-04-21    19.00
# ...             ...
# 2024-09-20    76.67
# 2024-09-23    62.67
# 2024-09-24    77.67
# 2024-09-25    79.00
# 2024-09-26    80.00
#
# [4006 rows x 1 columns]

# %%
df_potato.fillna(df_potato.ewm(span=7, adjust=False).mean(), inplace=True)

# %%
df_potato
# Out:
#             Average
# Date
# 2013-04-15    15.00
# 2013-04-16    17.00
# 2013-04-17    18.00
# 2013-04-18    19.00
# 2013-04-21    19.00
# ...             ...
# 2024-09-20    76.67
# 2024-09-23    62.67
# 2024-09-24    77.67
# 2024-09-25    79.00
# 2024-09-26    80.00
#
# [4006 rows x 1 columns]

# %%
data = df_potato.to_dict(orient='records')
data
# Out:
# [{'Date': '04/15/2013', 'Average': 'रू १५.००'},
#  {'Date': '04/16/2013', 'Average': 'रू १७.००'},
#  {'Date': '04/17/2013', 'Average': 'रू १८.००'},
#  {'Date': '04/18/2013', 'Average': 'रू १९.००'},
#  {'Date': '04/21/2013', 'Average': 'रू १९.००'},
#  {'Date': '04/22/2013', 'Average': 'रू १९.००'},
#  {'Date': '04/23/2013', 'Average': 'रू १९.००'},
#  {'Date': '04/25/2013', 'Average': 'रू १८.००'},
#  {'Date': '04/26/2013', 'Average': 'रू १९.००'},
#  {'Date': '04/28/2013', 'Average': 'रू १८.००'},
#  {'Date': '04/29/2013', 'Average': 'रू १८.००'},
#  {'Date': '04/30/2013', 'Average': 'रू १८.००'},
#  {'Date': '05/02/2013', 'Average': 'रू १९.००'},
#  {'Date': '05/03/2013', 'Average': 'रू १९.००'},
#  {'Date': '05/05/2013', 'Average': 'रू १९.००'},
#  {'Date': '05/06/2013', 'Average': 'रू १९.००'},
#  {'Date': '05/07/2013', 'Average': 'रू १९.००'},
#  {'Date': '05/08/2013', 'Average': 'रू १८.००'},
#  {'Date': '05/09/2013', 'Average': 'रू १९.००'},
#  {'Date': '05/10/2013', 'Average': 'रू १८.००'},
# ...

# %%
from urllib.parse import quote_plus

# Your username and password
username = "bishwajyotichaudhary46"
password = "Bismuth@123"

# Escape the username and password according to RFC 3986
escaped_username = quote_plus(username)
escaped_password = quote_plus(password)

# %%
escaped_password
# Out:
# 'Bismuth%40123'

# %%
import pandas as pd

# %%
DB_NAME = "Kalimati-Database"
COLLECTION_NAME = "kalimati_data"
CONNECTION_URL = f"mongodb+srv://{escaped_username}:{escaped_password}@cluster0.tofa7.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
CONNECTION_URL
# Out:
# 'mongodb+srv://bishwajyotichaudhary46:Bismuth%40123@cluster0.tofa7.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
import pymongo

# %%
from dotenv import load_dotenv

from pathlib import Path
from urllib.parse import quote_plus

# %%
import os

# %%
load_dotenv()
username = os.getenv('username')
password = os.getenv('password')

# Escape the username and password according to RFC 3986
escaped_username = quote_plus(username)
escaped_password = quote_plus(password)

# %%
escaped_username
# Out:
# 'bishwajyotichaudhary46'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'f:\\Unversity\\Project\\TimeSeries\\Kalimati-tarkari'

# %%
from kalimati_tarkari.constants import COLLECTION_NAME,MONGODB_URL_KEY, DATABASE_NAME

# %%
MONGODB_URL_KEY
# Out:
# 'mongodb+srv://bishwajyotichaudhary46:Bismuth%40123@cluster0.tofa7.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
client = pymongo.MongoClient(MONGODB_URL_KEY)
data_base = client[DATABASE_NAME]
collection = data_base[COLLECTION_NAME]

# %%
fetch_data = pd.DataFrame(list(collection.find()))
fetch_data
# Out:
#                            _id        Date   Average
# 0     672f7d550651d64efce7769c  04/15/2013  रू १५.००
# 1     672f7d550651d64efce7769d  04/16/2013  रू १७.००
# 2     672f7d550651d64efce7769e  04/17/2013  रू १८.००
# 3     672f7d550651d64efce7769f  04/18/2013  रू १९.००
# 4     672f7d550651d64efce776a0  04/21/2013  रू १९.००
# ...                        ...         ...       ...
# 4045  672f7d550651d64efce78669  11/05/2024  रू ८७.६७
# 4046  672f7d550651d64efce7866a  11/06/2024  रू ७७.६७
# 4047  672f7d550651d64efce7866b  11/07/2024  रू ७७.६७
# 4048  672f7d550651d64efce7866c  11/08/2024  रू ८३.००
# 4049  672f7d550651d64efce7866d  11/09/2024  रू ७९.००
#
# [4050 rows x 3 columns]
